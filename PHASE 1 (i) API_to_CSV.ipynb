# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.binance.us/api/v3/ticker/24hr')
print(response.json())
# Out:
# [{'symbol': 'BTCUSD4', 'priceChange': '0.0000', 'priceChangePercent': '0.000', 'weightedAvgPrice': '0.0000', 'prevClosePrice': '22882.5400', 'lastPrice': '0.0000', 'lastQty': '0.00000000', 'bidPrice': '0.0000', 'bidQty': '0.00000000', 'askPrice': '0.0000', 'askQty': '0.00000000', 'openPrice': '0.0000', 'highPrice': '0.0000', 'lowPrice': '0.0000', 'volume': '0.00000000', 'quoteVolume': '0.0000', 'openTime': 1683339785359, 'closeTime': 1683426185359, 'firstId': -1, 'lastId': -1, 'count': 0}, {'symbol': 'ETHUSD4', 'priceChange': '0.0000', 'priceChangePercent': '0.000', 'weightedAvgPrice': '0.0000', 'prevClosePrice': '1626.0300', 'lastPrice': '0.0000', 'lastQty': '0.00000000', 'bidPrice': '0.0000', 'bidQty': '0.00000000', 'askPrice': '0.0000', 'askQty': '0.00000000', 'openPrice': '0.0000', 'highPrice': '0.0000', 'lowPrice': '0.0000', 'volume': '0.00000000', 'quoteVolume': '0.0000', 'openTime': 1683339785359, 'closeTime': 1683426185359, 'firstId': -1, 'lastId': -1, 'count': 0}, {'symbol':
# ...

# %%
data=pd.DataFrame(response.json())
data.head()
# Out:
#     symbol priceChange priceChangePercent weightedAvgPrice prevClosePrice  \
# 0  BTCUSD4      0.0000              0.000           0.0000     22882.5400
# 1  ETHUSD4      0.0000              0.000           0.0000      1626.0300
# 2   XRPUSD      0.0000              0.000           0.0000         0.2970
# 3  BCHUSD4      0.0000              0.000           0.0000       134.2000
# 4  LTCUSD4      0.0000              0.000           0.0000        96.2100
#
#   lastPrice     lastQty bidPrice      bidQty askPrice  ... openPrice  \
# 0    0.0000  0.00000000   0.0000  0.00000000   0.0000  ...    0.0000
# 1    0.0000  0.00000000   0.0000  0.00000000   0.0000  ...    0.0000
# 2    0.0000  0.00000000   0.0000  0.00000000   0.0000  ...    0.0000
# 3    0.0000  0.00000000   0.0000  0.00000000   0.0000  ...    0.0000
# 4    0.0000  0.00000000   0.0000  0.00000000   0.0000  ...    0.0000
#
#   highPrice lowPrice      volume quoteVolume       openTime      closeTime  \
# ...

# %%
data.describe()
# Out:
#            openTime     closeTime       firstId        lastId         count
# count  5.370000e+02  5.370000e+02  5.370000e+02  5.370000e+02    537.000000
# mean   1.689164e+12  1.689250e+12  1.230723e+06  1.230949e+06    226.601490
# std    5.694846e+09  5.694846e+09  5.354069e+06  5.355480e+06   1563.389779
# min    1.683340e+12  1.683426e+12 -1.000000e+00 -1.000000e+00      0.000000
# 25%    1.683340e+12  1.683426e+12 -1.000000e+00 -1.000000e+00      0.000000
# 50%    1.687750e+12  1.687837e+12  1.448100e+04  1.448300e+04      6.000000
# 75%    1.696777e+12  1.696863e+12  2.726250e+05  2.726750e+05     73.000000
# max    1.696778e+12  1.696865e+12  8.853116e+07  8.855978e+07  28615.000000

# %%
data.to_csv('API_DATA_TO_CSV.csv', sep=',', index=False)

# %%
pd.read_csv('API_data_to_CSV.csv')
# Out:
#         symbol  priceChange  priceChangePercent  weightedAvgPrice  \
# 0      BTCUSD4     0.000000               0.000          0.000000
# 1      ETHUSD4     0.000000               0.000          0.000000
# 2       XRPUSD     0.000000               0.000          0.000000
# 3      BCHUSD4     0.000000               0.000          0.000000
# 4      LTCUSD4     0.000000               0.000          0.000000
# ..         ...          ...                 ...               ...
# 532    ZILUSDT    -0.000760              -4.548          0.016556
# 533   ORBSUSDT    -0.004110             -12.990          0.028941
# 534  CUDOSUSDT    -0.000116              -4.947          0.002307
# 535    ADXUSDT    -0.004200              -3.015          0.136786
# 536   FORTUSDT    -0.009400              -8.210          0.109371
#
#      prevClosePrice  lastPrice  lastQty  bidPrice  bidQty  askPrice  ...  \
# 0      22882.540000   0.000000      0.0  0.000000     0.0  0.000000  ...
# ...
